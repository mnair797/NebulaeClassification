# %%
import numpy as np
from skimage.io import imread, imshow
from skimage.filters import prewitt_h,prewitt_v
import matplotlib.pyplot as plt
# %matplotlib inline

#reading the image 
image = imread('hubble28.jpeg',as_gray=True)

#calculating horizontal edges using prewitt kernel
edges_prewitt_horizontal = prewitt_h(image)
#calculating vertical edges using prewitt kernel
edges_prewitt_vertical = prewitt_v(image)

imshow(edges_prewitt_vertical, cmap='gray')

# %%
from PIL import Image
from skimage.io import imread, imshow

img = Image.open('hubble28.jpeg').convert('L')
img.save('grayhubble28.jpeg')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = '/content/drive/My Drive/Nebulas'
PATH2 = '/content/drive/My Drive/GrayNebulas'

# %%
import os
from PIL import Image
from skimage.io import imread, imshow

og=os.path.join(PATH)

for classname in os.listdir(og):
  for filename in os.listdir(PATH+"/"+classname):
      if filename.endswith(".jpeg"):
        img = Image.open(PATH+"/"+classname+"/"+filename).convert('L')
        img.save(PATH2 + "/" + classname + "/" + filename)
      else:
        continue
